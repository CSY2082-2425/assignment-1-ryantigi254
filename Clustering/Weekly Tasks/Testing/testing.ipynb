# %% [markdown]
# ##### <span style="color: #FF0000;">Testing for Real Estate Price Prediction Model</span>
# ##### This section performs unit tests for the Real Estate Price Prediction Model:
#
# ##### <span style="color: #1E90FF;">Test Coverage:</span>
# ##### • Data cleaning processes
# ##### • Exploratory data analysis functions
# ##### • Price prediction functionality
#
# ##### <span style="color: #1E90FF;">Main Components Tested:</span>
# ##### • ExploratoryDataAnalysis class
# ##### • model_price_prediction function
#
# ##### <span style="color: #1E90FF;">Purpose:</span>
# ##### • Ensure robustness and reliability of the prediction system
# ##### • Demonstrate best practices in software development
# ##### • Validate quality and accuracy of the codebase
#
# ##### Note: While unit testing is an industry standard, it's not a required component of the weekly task. It's included here to showcase professional software development practices.

# %%
# Install required packages~
# %pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys

print("Current Working Directory:", os.getcwd())
print("sys.path:", sys.path)
# Out:
# Current Working Directory: e:\Uni\2nd year\Intro to AI\Regression\assignment-1-ryantigi254\Regression\Weekly Tasks\Testing
# sys.path: ['c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\python312.zip', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\DLLs', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\Lib', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env', '', 'C:\\Users\\ryant\\AppData\\Roaming\\Python\\Python312\\site-packages', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\Lib\\site-packages', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\Lib\\site-packages\\win32', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\ryant\\.conda\\envs\\piicatcher_env\\Lib\\site-packages\\Pythonwin']

# %%
# Out:
# Starting EDA...
# Data cleaned successfully.
# EDA completed successfully.
# Linear Regression - MSE: 9.691e+11, R2: 0.1223
# Polynomial Regression - MSE: 7.644e+11, R2: 0.3076
# SGD Regression - MSE: 1.92e+12, R2: -0.7388
# .
# .
# Starting EDA...
# Data cleaned successfully.
# .
# EDA completed successfully.
# Linear Regression - MSE: 9.691e+11, R2: 0.1223
# Polynomial Regression - MSE: 7.644e+11, R2: 0.3076
# SGD Regression - MSE: 1.92e+12, R2: -0.7388
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 2.432s
#
# OK
